# %% [markdown]
# <a href="https://colab.research.google.com/github/Izhamfath/DS-project1/blob/main/Data_science_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/Colab Notebooks/Mobile_phone_price.csv'
df = pd.read_csv(file_path)
df
# Out:
# Mounted at /content/drive
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# ...

# %%
df.shape
# Out:
# (407, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 25.6+ KB

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Battery Capacity (mAh)
# count              407.000000
# mean              4676.476658
# std                797.193713
# min               1821.000000
# 25%               4300.000000
# 50%               5000.000000
# 75%               5000.000000
# max               7000.000000

# %% [markdown]
# Analisis kolom storage

# %%
df['Storage '].unique()
# Out:
# array(['128 GB', '256 GB', '64 GB', '32 GB', '128GB', '256GB', '64GB',
#        '32GB', '256', '64', '128', '512', '32'], dtype=object)

# %%
df['Storage '] = df['Storage '].str.replace(' ', '')
df['Storage '].unique()
# Out:
# array(['128GB', '256GB', '64GB', '32GB', '256', '64', '128', '512', '32'],
#       dtype=object)

# %%
df['Storage '] = df['Storage '].str.replace('GB', '')
df['Storage '].unique()
# Out:
# array(['128', '256', '64', '32', '512'], dtype=object)

# %%
df['Storage '] = df['Storage '].astype(int)
df['Storage '].unique()
# Out:
# array([128, 256,  64,  32, 512])

# %%
print(df['Storage '].dtype)
# Out:
# int64

# %%
df['Storage '].unique()
# Out:
# array([128, 256,  64,  32, 512])

# %% [markdown]
# Analisis kolom RAM

# %%
df['RAM '].unique()
# Out:
# array(['6 GB', '12 GB', '8 GB', '4 GB', '3 GB', '2 GB', '4GB', '8GB',
#        '6GB', '12GB', '3GB', '2GB', '5GB', '12', '3', '6', '8', '4', '16',
#        '2'], dtype=object)

# %%
df['RAM '] = df['RAM '].str.replace(' ', '')
df['RAM '] = df['RAM '].str.replace('GB', '')

# %%
df['RAM '] = df['RAM '].astype(int)

# %%
df.describe()
# Out:
#          Storage         RAM   Battery Capacity (mAh)
# count  407.000000  407.000000              407.000000
# mean   123.046683    5.837838             4676.476658
# std     64.963160    2.431980              797.193713
# min     32.000000    2.000000             1821.000000
# 25%     64.000000    4.000000             4300.000000
# 50%    128.000000    6.000000             5000.000000
# 75%    128.000000    8.000000             5000.000000
# max    512.000000   16.000000             7000.000000

# %% [markdown]
# Analisis Price

# %%
df['Price ($)'].unique()
# Out:
# array(['999', '1199', '899', '279', '799', '249', '699', '329', '449',
#        '199', '299', '379', '179', '729', '599', '139', '189', '399',
#        '259', '159', '229', '499', '129', '529', '369', '1099', '169',
#        '99', '459', '239', '1299', '429', '659', '269', '359', '$799 ',
#        '$399 ', '$699 ', '$329 ', '$999 ', '$549 ', '$1,299 ', '$899 ',
#        '$449 ', '$319 ', '$269 ', '$349 ', '$279 ', '$249 ', '$299 ',
#        '$969 ', '$1,199 ', '$149 ', '$139 ', '$99 ', '$199 ', '$169 ',
#        '$499 ', '$179 ', '$219 ', '$229 ', '$239 ', '$109 ', '$189 ',
#        '$389 ', '$309 ', '$369 ', '$129 ', '$849 ', '$469 ', '$209 ',
#        '$119 ', '$339 ', '$429 ', '$159 ', '$379 ', '$289 ', '130', '749',
#        '149', '969', '649', '349', '419', '1399', '1999', '119', '319',
#        '1049'], dtype=object)

# %%
df['Price ($)'] = df['Price ($)'].str.replace(' ', '')
df['Price ($)'] = df['Price ($)'].str.replace('$', '')
df['Price ($)'] = df['Price ($)'].str.replace(',', '')
df['Price ($)'] = df['Price ($)'].astype(int)
df['Price ($)'].dtype
# Out:
# <ipython-input-18-fdff405fbdee>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price ($)'] = df['Price ($)'].str.replace('$', '')
# dtype('int64')

# %%
df.describe()
# Out:
#          Storage         RAM   Battery Capacity (mAh)    Price ($)
# count  407.000000  407.000000              407.000000   407.000000
# mean   123.046683    5.837838             4676.476658   408.314496
# std     64.963160    2.431980              797.193713   299.684768
# min     32.000000    2.000000             1821.000000    99.000000
# 25%     64.000000    4.000000             4300.000000   199.000000
# 50%    128.000000    6.000000             5000.000000   299.000000
# 75%    128.000000    8.000000             5000.000000   499.000000
# max    512.000000   16.000000             7000.000000  1999.000000

# %% [markdown]
# Analisis screen size (skip)

# %% [markdown]
# Sorting

# %%
df.sort_values(by = ['Battery Capacity (mAh)'], ascending = False)
# Out:
#         Brand                Model  Storage   RAM  Screen Size (inches)  \
# 208   Samsung           Galaxy M62       128     8                  6.7
# 334   Samsung           Galaxy M51       128     6                  6.7
# 205  Motorola             Moto G60       128     6                  6.8
# 35     Realme                 C25s       128     4                  6.5
# 372  Motorola        Moto G9 Power       128     4                  6.8
# ..        ...                  ...       ...   ...                  ...
# 32      Apple  iPhone SE (2nd Gen)        64     3                  4.7
# 62      Apple     iPhone SE (2020)        64     3                  4.7
# 289     Apple     iPhone SE (2020)        64     3                  4.7
# 333     Apple     iPhone SE (2020)        64     3                  4.7
# 379     Apple     iPhone SE (2020)       128     3                  4.7
#
#                  Camera (MP)  Battery Capacity (mAh)  Price ($)
# ...

# %%
#example, sort by batery terbesar dengan harga termurah
df.sort_values(by = ['Battery Capacity (mAh)', 'Price ($)'], ascending = [False, True])
# Out:
#        Brand                Model  Storage   RAM  Screen Size (inches)  \
# 208  Samsung           Galaxy M62       128     8                  6.7
# 334  Samsung           Galaxy M51       128     6                  6.7
# 119   Realme            Narzo 50A        64     4                  6.5
# 128    Nokia                  C30        64     3                 6.82
# 175   Realme                 C25s       128     4                  6.5
# ..       ...                  ...       ...   ...                  ...
# 32     Apple  iPhone SE (2nd Gen)        64     3                  4.7
# 62     Apple     iPhone SE (2020)        64     3                  4.7
# 289    Apple     iPhone SE (2020)        64     3                  4.7
# 333    Apple     iPhone SE (2020)        64     3                  4.7
# 379    Apple     iPhone SE (2020)       128     3                  4.7
#
#                  Camera (MP)  Battery Capacity (mAh)  Price ($)
# ...

# %% [markdown]
# Filter

# %%
df.loc[df['Brand']=='Xiaomi'].sort_values(by = 'Price ($)', ascending = True)
# Out:
#       Brand          Model  Storage   RAM  Screen Size (inches)  \
# 380  Xiaomi       Redmi 9C        64     3                 6.53
# 218  Xiaomi       Redmi 9i        64     4                 6.53
# 152  Xiaomi  Redmi 9 Activ        64     4                 6.53
# 275  Xiaomi        Redmi 9        64     4                 6.53
# 397  Xiaomi        Poco M3       128     4                 6.53
# ..      ...            ...       ...   ...                  ...
# 44   Xiaomi         Mi 11X       128     8                 6.67
# 325  Xiaomi     Mi 10T Pro       256     8                 6.67
# 374  Xiaomi  Mi 10T Pro 5G       128     8                 6.67
# 298  Xiaomi          Mi 11       256     8                 6.81
# 104  Xiaomi    Mi 11 Ultra       256    12                 6.81
#
#                 Camera (MP)  Battery Capacity (mAh)  Price ($)
# 380                  13+2+2                    5000        119
# 218                    13MP                    5000        139
# ...

# %%
#memfilter data berdasarkan brand dengan kondisi harga lebih dari 190 dan kurang dari 900 dengan tampilan kolom Brand, Model, dan harga kemudian diurutkan dari terkecil ke terbesar
df.loc[(df['Brand'] == 'Xiaomi') & (df['Price ($)'] > 190) & (df['Price ($)'] < 900), ['Brand', 'Model', 'Price ($)']]
df.sort_values(by = 'Price ($)', ascending = True)
# Out:
#        Brand                Model  Storage   RAM  Screen Size (inches)  \
# 250   Realme             C11 2021        32     2                  6.5
# 240    Nokia             C20 Plus        32     3                  6.5
# 216   Realme             C11 2021        32     2                 6.52
# 53    Realme            Narzo 50i        32     2                  6.5
# 273   Realme                  C11        32     2                  6.5
# ..       ...                  ...       ...   ...                  ...
# 57     Apple    iPhone 13 Pro Max       256     6                  6.7
# 87      Sony         Xperia 5 III       128     8                  6.1
# 367  Samsung  Galaxy S20 Ultra 5G       512    16                  6.9
# 361   Huawei             P40 Pro+       512     8                 6.58
# 373  Samsung    Galaxy Z Fold2 5G       256    12       7.6 (unfolded)
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)
# ...

# %%
df.iloc[2:10,0:4]
# Out:
#      Brand              Model  Storage   RAM
# 2  OnePlus              9 Pro       128     8
# 3   Xiaomi  Redmi Note 10 Pro       128     6
# 4   Google            Pixel 6       128     8
# 5    Apple          iPhone 13       128     4
# 6  Samsung     Galaxy Z Flip3       256     8
# 7   Xiaomi        Poco X3 Pro       128     6
# 8     Oppo      Reno6 Pro+ 5G       128     8
# 9     Vivo           X70 Pro+       256    12

# %%
df['Battery dollar'] = df['Battery Capacity (mAh)'] / df['Price ($)']

# %%
df.sort_values(by = 'Battery dollar', ascending = False)
# Out:
#         Brand              Model  Storage   RAM  Screen Size (inches)  \
# 273    Realme                C11        32     2                  6.5
# 216    Realme           C11 2021        32     2                 6.52
# 53     Realme          Narzo 50i        32     2                  6.5
# 109  Motorola     Moto E7i Power        32     2                  6.5
# 250    Realme           C11 2021        32     2                  6.5
# ..        ...                ...       ...   ...                  ...
# 361    Huawei           P40 Pro+       512     8                 6.58
# 338     Apple      iPhone XS Max       256     4                  6.5
# 384     Apple      iPhone 12 Pro       128     6                  6.1
# 369     Apple     iPhone 12 mini       256     4                  5.4
# 373   Samsung  Galaxy Z Fold2 5G       256    12       7.6 (unfolded)
#
#      Camera (MP)  Battery Capacity (mAh)  Price ($)  Battery dollar
# ...

# %% [markdown]
# Grouping

# %%
df.groupby('Brand').agg(Avg_prices = ('Price ($)','mean')).sort_values(by = 'Avg_prices')
# Out:
#              Avg_prices
# Brand
# Realme       206.906977
# Nokia        244.714286
# Motorola     278.130435
# Xiaomi       282.880597
# CAT          299.000000
# Vivo         323.000000
# Oppo         376.142857
# Samsung      480.405063
# Blackberry   499.000000
# LG           615.666667
# OnePlus      644.333333
# Google       699.000000
# Apple        745.666667
# Huawei       783.166667
# Asus         874.000000
# Sony        1299.000000

# %%
df.groupby('Brand').agg(Avg_prices = ('Price ($)','mean'), Avg_Battery_Capacity = ('Battery Capacity (mAh)','mean'))
# Out:
#              Avg_prices  Avg_Battery_Capacity
# Brand
# Apple        745.666667           2863.900000
# Asus         874.000000           5000.000000
# Blackberry   499.000000           3500.000000
# CAT          299.000000           4200.000000
# Google       699.000000           4019.857143
# Huawei       783.166667           4161.666667
# LG           615.666667           4100.000000
# Motorola     278.130435           5021.739130
# Nokia        244.714286           4502.857143
# OnePlus      644.333333           4415.000000
# Oppo         376.142857           4631.339286
# Realme       206.906977           5176.744186
# Samsung      480.405063           4936.708861
# Sony        1299.000000           4500.000000
# Vivo         323.000000           4750.000000
# Xiaomi       282.880597           5101.791045

# %%
df
# Out:
#        Brand              Model  Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro       128     6                  6.1
# 1    Samsung   Galaxy S21 Ultra       256    12                  6.8
# 2    OnePlus              9 Pro       128     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro       128     6                 6.67
# 4     Google            Pixel 6       128     8                  6.4
# ..       ...                ...       ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G       128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G       128     6                 6.57
# 404    Apple  iPhone 12 Pro Max       128     6                  6.7
# 405     Oppo              Reno3       128     8                  6.4
# 406  Samsung    Galaxy S10 Lite       128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  Battery dollar
# ...

# %%
df['RAM '].unique()
# Out:
# array([ 6, 12,  8,  4,  3,  2,  5, 16])

# %%
pd.crosstab(df['Brand'],df['RAM '])
# Out:
# RAM         2   3   4   5   6   8   12  16
# Brand
# Apple        0  11  14   0   5   0   0   0
# Asus         0   0   0   0   1   3   0   0
# Blackberry   0   0   1   0   2   0   0   0
# CAT          0   1   0   0   0   0   0   0
# Google       0   0   0   0   2   5   0   0
# Huawei       0   0   2   0   0  10   0   0
# LG           0   0   0   0   2   1   0   0
# Motorola     1   2  14   2   3   0   1   0
# Nokia        4   8  10   0   4   2   0   0
# OnePlus      0   0   0   0   3   8   4   0
# Oppo         0   4  13   0  14  15  10   0
# Realme       5   2  20   0   5  11   0   0
# Samsung      1   4  26   0  29  12   6   1
# Sony         0   0   0   0   0   1   0   0
# Vivo         0   5   5   0   4  18   3   0
# Xiaomi       0   1  23   0  33   9   1   0

# %%
df.pivot_table(index = 'Brand', values = 'Price ($)', aggfunc = 'mean')
# Out:
#               Price ($)
# Brand
# Apple        745.666667
# Asus         874.000000
# Blackberry   499.000000
# CAT          299.000000
# Google       699.000000
# Huawei       783.166667
# LG           615.666667
# Motorola     278.130435
# Nokia        244.714286
# OnePlus      644.333333
# Oppo         376.142857
# Realme       206.906977
# Samsung      480.405063
# Sony        1299.000000
# Vivo         323.000000
# Xiaomi       282.880597

# %%
df.groupby('Brand').agg(avg_prices = ('Price ($)', 'mean'))
# Out:
#              avg_prices
# Brand
# Apple        745.666667
# Asus         874.000000
# Blackberry   499.000000
# CAT          299.000000
# Google       699.000000
# Huawei       783.166667
# LG           615.666667
# Motorola     278.130435
# Nokia        244.714286
# OnePlus      644.333333
# Oppo         376.142857
# Realme       206.906977
# Samsung      480.405063
# Sony        1299.000000
# Vivo         323.000000
# Xiaomi       282.880597

# %%
df.pivot_table(index = 'Brand', values = 'Price ($)', aggfunc = 'mean', columns = 'RAM ')
# Out:
# RAM            2           3           4      5            6            8   \
# Brand
# Apple         NaN  494.454545  838.285714    NaN  1039.000000          NaN
# Asus          NaN         NaN         NaN    NaN   699.000000   932.333333
# Blackberry    NaN         NaN  399.000000    NaN   549.000000          NaN
# CAT           NaN  299.000000         NaN    NaN          NaN          NaN
# Google        NaN         NaN         NaN    NaN   649.000000   719.000000
# Huawei        NaN         NaN  264.000000    NaN          NaN   887.000000
# LG            NaN         NaN         NaN    NaN   424.000000   999.000000
# Motorola     99.0  184.000000  239.714286  399.0   359.000000          NaN
# Nokia       134.0  142.750000  228.000000    NaN   474.000000   499.000000
# OnePlus       NaN         NaN         NaN    NaN   309.000000   631.500000
# Oppo          NaN  151.500000  190.538462    NaN   272.571429   407.666667
# ...

# %%
df
# Out:
#        Brand              Model  Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro       128     6                  6.1
# 1    Samsung   Galaxy S21 Ultra       256    12                  6.8
# 2    OnePlus              9 Pro       128     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro       128     6                 6.67
# 4     Google            Pixel 6       128     8                  6.4
# ..       ...                ...       ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G       128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G       128     6                 6.57
# 404    Apple  iPhone 12 Pro Max       128     6                  6.7
# 405     Oppo              Reno3       128     8                  6.4
# 406  Samsung    Galaxy S10 Lite       128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  Battery dollar
# ...

# %% [markdown]
# Melting

# %%
df_melt = df.melt(id_vars = ['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)', 'Camera (MP)'],\
       var_name = 'atribut', value_name = 'nilai')

# %%
df_melt
# Out:
#         Brand              Model  Storage   RAM  Screen Size (inches)  \
# 0       Apple      iPhone 13 Pro       128     6                  6.1
# 1     Samsung   Galaxy S21 Ultra       256    12                  6.8
# 2     OnePlus              9 Pro       128     8                  6.7
# 3      Xiaomi  Redmi Note 10 Pro       128     6                 6.67
# 4      Google            Pixel 6       128     8                  6.4
# ...       ...                ...       ...   ...                  ...
# 1216  Samsung   Galaxy Note20 5G       128     8                  6.7
# 1217   Xiaomi      Mi 10 Lite 5G       128     6                 6.57
# 1218    Apple  iPhone 12 Pro Max       128     6                  6.7
# 1219     Oppo              Reno3       128     8                  6.4
# 1220  Samsung    Galaxy S10 Lite       128     6                  6.7
#
#              Camera (MP)                 atribut        nilai
# 0           12 + 12 + 12  Battery Capacity (mAh)  3095.000000
# ...

# %%
df_melt.loc[407:408]
# Out:
#        Brand             Model  Storage   RAM  Screen Size (inches)  \
# 407    Apple     iPhone 13 Pro       128     6                  6.1
# 408  Samsung  Galaxy S21 Ultra       256    12                  6.8
#
#             Camera (MP)    atribut   nilai
# 407        12 + 12 + 12  Price ($)   999.0
# 408  108 + 10 + 10 + 12  Price ($)  1199.0

# %% [markdown]
# Stack

# %%
df_stacked = df.set_index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)', 'Camera (MP)']).stack().reset_index()
df_stacked = df_stacked.rename(columns = {'level_6':'atribut', 0:'nilai'})
df_stacked
# Out:
#         Brand             Model  Storage   RAM  Screen Size (inches)  \
# 0       Apple     iPhone 13 Pro       128     6                  6.1
# 1       Apple     iPhone 13 Pro       128     6                  6.1
# 2       Apple     iPhone 13 Pro       128     6                  6.1
# 3     Samsung  Galaxy S21 Ultra       256    12                  6.8
# 4     Samsung  Galaxy S21 Ultra       256    12                  6.8
# ...       ...               ...       ...   ...                  ...
# 1216     Oppo             Reno3       128     8                  6.4
# 1217     Oppo             Reno3       128     8                  6.4
# 1218  Samsung   Galaxy S10 Lite       128     6                  6.7
# 1219  Samsung   Galaxy S10 Lite       128     6                  6.7
# 1220  Samsung   Galaxy S10 Lite       128     6                  6.7
#
#              Camera (MP)                 atribut        nilai
# 0           12 + 12 + 12  Battery Capacity (mAh)  3095.000000
# ...

# %% [markdown]
# Ranking

# %%
df
# Out:
#        Brand              Model  Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro       128     6                  6.1
# 1    Samsung   Galaxy S21 Ultra       256    12                  6.8
# 2    OnePlus              9 Pro       128     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro       128     6                 6.67
# 4     Google            Pixel 6       128     8                  6.4
# ..       ...                ...       ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G       128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G       128     6                 6.57
# 404    Apple  iPhone 12 Pro Max       128     6                  6.7
# 405     Oppo              Reno3       128     8                  6.4
# 406  Samsung    Galaxy S10 Lite       128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  Battery dollar
# ...

# %%
df['ranking'] = df['Battery dollar'].rank(ascending = False, method = 'dense')
df.sort_values(by = 'ranking').head(20)
# Out:
#         Brand               Model  Storage   RAM  Screen Size (inches)  \
# 109  Motorola      Moto E7i Power        32     2                  6.5
# 250    Realme            C11 2021        32     2                  6.5
# 53     Realme           Narzo 50i        32     2                  6.5
# 216    Realme            C11 2021        32     2                 6.52
# 261    Realme                 C20        32     2                  6.5
# 273    Realme                 C11        32     2                  6.5
# 107     Nokia            C20 Plus        32     3                  6.5
# 240     Nokia            C20 Plus        32     3                  6.5
# 139     Nokia            C20 Plus        32     3                  6.5
# 380    Xiaomi            Redmi 9C        64     3                 6.53
# 199    Realme                C21Y        64     4                  6.5
# 397    Xiaomi             Poco M3       128     4                 6.53
# ...
